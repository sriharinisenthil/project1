# %% [markdown]
# ## operation on List

# %% [markdown]
# Create a list

# %%
my_list = [10,20,30,40]
print("created List:",my_list)
# Out:
# created List: [10, 20, 30, 40]

# %% [markdown]
# Append an element

# %%
my_list =[10,20,30,40]
print("after Append:",my_list)
# Out:
# after Append: [10, 20, 30, 40]

# %% [markdown]
# Insert element

# %%
my_list=[10,20,30,40]
my_list.insert(2,25)
print("after Remove:",my_list)
# Out:
# after Remove: [10, 20, 25, 30, 40]

# %% [markdown]
# Reverse the list

# %%
my_list=[10,20,30,40]
my_list.reverse()
print("After the reverse:",my_list)
# Out:
# After the reverse: [40, 30, 20, 10]

# %% [markdown]
# ## operation on tuple

# %% [markdown]
# create the tuple

# %%
my_tuple=(1,2,3,4,5)
print("Created Tuple:",my_tuple)
# Out:
# Created Tuple: (1, 2, 3, 4, 5)

# %% [markdown]
# Indexing

# %%
my_tuple=(1,2,3,4,5)
print("Element at index 2:",my_tuple[2])
# Out:
# Element at index 2: 3

# %% [markdown]
# Slicing

# %%
my_tuple=(1,2,3,4,5)
print("slice(1:4):",my_tuple[1:4])
# Out:
# slice(1:4): (2, 3, 4)

# %% [markdown]
# count

# %%
my_tuple=(1,2,3,4,5)
print("count of 3:",my_tuple.count(3))
# Out:
# count of 3: 1

# %% [markdown]
# length

# %%
my_tuple=(1,2,3,4,5)
print("length of tuple:",len(my_tuple))
# Out:
# length of tuple: 5

# %% [markdown]
# # Operation on Set

# %% [markdown]
# Create a set

# %%
my_set={10,20,30,40}
print("Created set:",my_set)
# Out:
# Created set: {40, 10, 20, 30}

# %% [markdown]
# Add element

# %%
my_set={10,20,30,40}
my_set.add(50)
print("After add:",my_set)
# Out:
# After add: {40, 10, 50, 20, 30}

# %% [markdown]
# Remove element

# %%
my_set={10,20,30,40}
my_set.remove(20)
print("After remove:",my_set)
# Out:
# After remove: {40, 10, 30}

# %%
set1 ={10,20,30}
set2 ={30,40,50}
print("Union:",set1.union(set2))
# Out:
# Union: {50, 20, 40, 10, 30}

# %% [markdown]
# Intersection

# %%
set1 ={10,20,30}
set2 ={30,40,50}
print("intersection:",set1.intersection(set2))
# Out:
# intersection: {30}

# %% [markdown]
# # Operation on dictionary

# %% [markdown]
# Create dictionary

# %%
my_dict = {"name": "SRI HARINI", "age": 19, "dept": "CSE"}
print("Created Dictionary:", my_dict)
# Out:
# Created Dictionary: {'name': 'SRI HARINI', 'age': 19, 'dept': 'CSE'}

# %% [markdown]
# Access value

# %%
my_dict = {"name": "SRI HARINI", "age": 19, "dept": "CSE"}
print("Name:", my_dict["name"])
# Out:
# Name: SRI HARINI

# %% [markdown]
# Add new key-value

# %%
my_dict = {"name": "SRI HARINI", "age": 19, "dept": "CSE"}
my_dict["college"] = "PMIST University"
print("After Adding:", my_dict)
# Out:
# After Adding: {'name': 'SRI HARINI', 'age': 19, 'dept': 'CSE', 'college': 'PMIST University'}

# %% [markdown]
# Update value

# %%
my_dict = {"name": "SRI HARINI", "age": 19, "dept": "CSE"}
my_dict["age"] = 20
print("After Update:", my_dict)
# Out:
# After Update: {'name': 'SRI HARINI', 'age': 20, 'dept': 'CSE'}

# %% [markdown]
# Delete a key

# %%
my_dict = {"name": "SRI HARINI", "age": 19, "dept": "CSE"}
del my_dict["dept"]
print("After Delete:", my_dict)
# Out:
# After Delete: {'name': 'SRI HARINI', 'age': 19}
